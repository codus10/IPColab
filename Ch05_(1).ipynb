# %% [markdown]
# <a href="https://colab.research.google.com/github/codus10/IPColab/blob/main/Ch05_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
gImg1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
cv2_imshow(gImg1)
# Out:
# (256, 256, 3)
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
def saturation(value):
  if value>255:
    return 255
  elif value<0:
    return 0
  else:
    return value

# %%
kernel3 = np.ones((3,3),np.float32)/9
kernel5 = np.ones((5,5),np.float32)/25
kernel7 = np.ones((7,7),np.float32)/49

# %%
kernel3 = np.ones((3,3),np.float32)/9

# %%
output = cv2.filter2D(gImg1,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(gImg1,-1,kernel5)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(gImg1,-1,kernel7)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output2 = cv2.filter2D(output,-1,kernel3)
cv2_imshow(output2)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gOut = np.zeros((gImg1.shape[0],gImg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(1,gImg1.shape[0]-1):
  for w in range(1,gImg1.shape[1]-1):
    sum = 0
    for i in range(-1,2):
      for j in range(-1,2):
        sum += gImg1[h+i,w+j] * kernel3[i+1,j+1]
    sum = saturation(sum)
    gOut[h,w] = sum
cv2_imshow(gOut)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(gImg1,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(gImg1,-1,kernel3)
plt.imshow(output, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/fcespnoise.bmp')
#img = cv2.imread('/content/gdrive/My Drive/IP/Images/LenaG2.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gImg1, cmap ='gray')
#cv2_imshow(gImg1)
# Out:
# (256, 256, 3)

# %%
outImg = cv2.blur(gImg1,(3,3))
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/fcespnoise.bmp')
#img = cv2.imread('/content/gdrive/My Drive/IP/Images/LenaG2.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gImg1, cmap ='gray')
#cv2_imshow(gImg1)
# Out:
# (256, 256, 3)

# %%
outImg = cv2.medianBlur(gImg1, 3)
#cv2_imshow(outImg)
plt.imshow(outImg, cmap ='gray')
