# %% [markdown]
# <a href="https://colab.research.google.com/github/codus10/IPColab/blob/main/Ch03_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/MyDrive/IP/Images/aero2.bmp')
print(img.shape)
glmg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(glmg1.shape)
plt.imshow(glmg1, cmap='gray')
# Out:
# (256, 256, 3)
# (256, 256)

# %%
img = cv2.imread('/content/gdrive/MyDrive/IP/Images/milkdrop.bmp')
print(img.shape)
glmg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(glmg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
gPlus = np.zeros((256, 256), dtype=np.ubyte)

# %%
gPlus_int16 = np.zeros((glmg1.shape[0], glmg1.shape[1]), dtype=np.int16)

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    #gPlus_int16[h,w] = glmg1[h,w].astype(np.int16) + glmg2[h,w].astype(np.int16)
    pValue = np.int32(glmg1[h,w]) + np.int32(glmg2[h,w])
    if pValue > 255:
      pValue = 255
    gPlus_int16[h,w] = pValue

plt.imshow(gPlus_int16, cmap='gray')

# %%
gPlus_int16 = np.zeros((glmg1.shape[0], glmg1.shape[1]), dtype=np.int16)

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    gPlus[h,w] = glmg1[h,w] * 0.5 + glmg2[h,w] * 0.5


plt.imshow(gPlus, cmap='gray')

# %%
gPlus = cv2.add(glmg1, glmg2)
plt.imshow(gPlus, cmap='gray')

# %%
gMius = np.zeros((glmg1.shape[0], glmg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    gMius[h,w] = np.abs(np.int32(glmg1[h,w]) - np.int32(glmg2[h,w]))


plt.imshow(gMius, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/MyDrive/IP/Images/milkdrop.bmp')
print(img.shape)
glmg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(glmg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
img = cv2.imread('/content/gdrive/MyDrive/IP/Images/milkdrop1.bmp')
print(img.shape)
glmg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(glmg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    gMius[h,w] = np.abs(np.int32(glmg1[h,w]) - np.int32(glmg2[h,w]))


plt.imshow(gMius, cmap='gray')

# %%
gMul = np.zeros((glmg1.shape[0], glmg1.shape[1]), dtype=np.ubyte)

# %%
img = cv2.imread('/content/gdrive/MyDrive/IP/Images/girl.jpg')
print(img.shape)
glmg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(glmg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.abs(np.int32(glmg1[h,w]) * 2)
    if mulVal > 255:
      mulVal = 255
    gMul[h,w] = mulVal


plt.imshow(gMul, cmap='gray')

# %%
val = 3

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.abs(np.int32(glmg1[h,w]) * val)
    if mulVal > 255:
      mulVal = 255
    gMul[h,w] = mulVal


plt.imshow(gMul, cmap='gray')

# %%
val = 1.5

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.abs(np.int32(glmg1[h,w]) * val)
    if mulVal > 255:
      mulVal = 255
    gMul[h,w] = mulVal


plt.imshow(gMul, cmap='gray')

# %%
val = 0.5

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.abs(np.int32(glmg1[h,w]) * val)
    if mulVal > 255:
      mulVal = 255
    gMul[h,w] = mulVal


plt.imshow(gMul, cmap='gray')

# %%
def saturation(val):
  if val > 255:
    return 255
  elif val < 0:
    return 0
  else:
   return val

# %%
val = 2

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.int32(glmg1[h,w]) * val
    #mulval = glmg1[h,w] * val
    gMul[h,w] = saturation(mulVal)

plt.imshow(gMul, cmap='gray')
#cv2_imshow(gMul)

# %%
val = 0.2

for h in range(glmg1.shape[0]):
  for w in range(glmg1.shape[1]):
    mulVal = np.int32(glmg1[h,w]) * val
    #mulval = glmg1[h,w] * val
    gMul[h,w] = saturation(mulVal)

#plt.imshow(gMul, cmap='gray')
plt.imshow(gMul,cmap='gray', vmin=0, vmax=255)
#cv2_imshow(gMul)
